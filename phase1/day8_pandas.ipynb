# %%
import subprocess
subprocess.run(["d:\\machinelearning\\ai_env\\Scripts\\pip.exe", "install", "pandas"])
# Out:
# CompletedProcess(args=['d:\\machinelearning\\ai_env\\Scripts\\pip.exe', 'install', 'pandas'], returncode=1)
